# %%
#Insertion Sort
from numpy import random
import time

a= []
n = int(input("enter the size of input"))
x=random.randint(100, size=(n))
a= x
a.sort()
a[::-1].sort()


def insertion_sort(a):
    for i in range(1,len(a)):
        key = a[i]
        j = i-1
        while(j>=0 and key < a[j]):
            a[j+1] = a[j]
            j -= 1
        a[j+1] = key

start_time =time.time()
insertion_sort(a)
runtime = (time.time() - start_time)*1000
print("runtime in ms := ",runtime)
# Out:
# enter the size of input50
# runtime in ms :=  2.9976367950439453

# %%
import matplotlib.pyplot as plt 
  
# x axis values 
x = [1,2,3] 
# corresponding y axis values 
y = [2,4,1] 
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('My first graph!') 
  
# function to show the plot 
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Merge Sort
import time
from numpy import random

a= []
n = int(input("enter the size of input"))
x=random.randint(100000, size=(n))
a= x

def merge_sort(a):
    if(len(a)>1):
        mid = len(a)//2
        lefth = a[:mid]
        righth = a[mid:]
        merge_sort(lefth)
        merge_sort(righth)
        i = j = k = 0
        while( i < len(lefth) and j < (len(righth))):
            if(lefth[i] < righth[j]):
                a[k] = lefth[i]
                i +=1
            else:
                a[k] = righth[j]
                j +=1
            k+=1
        while( i < len(lefth)):
            a[k] = lefth[i]
            i +=1
            k += 1
        while( j< len(righth)):
            a[k] = righth[j]
            j +=1
            k +=1

def insertion_sort(a):
    for i in range(1,len(a)):
        key = a[i]
        j = i-1
        while(j>=0 and key < a[j]):
            a[j+1] = a[j]
            j -= 1
        a[j+1] = key



start_time =time.time()            
merge_sort(a)
runtime = (time.time() - start_time)*1000
print(" runtime in ms =",runtime)
# Out:
# enter the size of input60000
#  runtime in ms = 3903.669595718384

# %%
#Heap Sort
import time
from numpy import random
a= []
n = int(input("enter the size of input"))
x=random.randint(100000, size=(n))
a= x

def heapify(nums, heap_size, root_index):
    # Assume the index of the largest element is the root index
    largest = root_index
    left_child = (2 * root_index) + 1
    right_child = (2 * root_index) + 2

    if left_child < heap_size and nums[left_child] > nums[largest]:
        largest = left_child

    if right_child < heap_size and nums[right_child] > nums[largest]:
        largest = right_child

    if largest != root_index:
        nums[root_index], nums[largest] = nums[largest], nums[root_index]
        heapify(nums, heap_size, largest)

def heap_sort(nums):
    n = len(nums)

    for i in range(n, -1, -1):
        heapify(nums, n, i)

    for i in range(n - 1, 0, -1):
        nums[i], nums[0] = nums[0], nums[i]
        heapify(nums, i, 0)



start_time =time.time()            
heap_sort(a)
runtime = (time.time() - start_time)*1000
print(" runtime in ms =",runtime)
# Out:
# enter the size of input500
#  runtime in ms = 39.99471664428711

# %%
#Inplace Quick Sort
import time
from numpy import random
a= []
n = int(input("enter the size of input"))
x=random.randint(100000, size=(n))
a= x


def partition(nums, low, high):
    
    pivot = nums[(low + high) // 2]
    i = low - 1
    j = high + 1
    while True:
        i += 1
        while nums[i] < pivot:
            i += 1

        j -= 1
        while nums[j] > pivot:
            j -= 1

        if i >= j:
            return j

        nums[i], nums[j] = nums[j], nums[i]


def quick_sort(nums):

    def _quick_sort(items, low, high):
        if low < high:
          
            split_index = partition(items, low, high)
            _quick_sort(items, low, split_index)
            _quick_sort(items, split_index + 1, high)

    _quick_sort(nums, 0, len(nums) - 1)

start_time =time.time()
quick_sort(a)
runtime=(time.time() - start_time)*1000

print("runtime in ms :",runtime)
# Out:
# enter the size of input5000
# runtime in ms : 71.97809219360352

# %%
#Modified Quicksort
import time
from numpy import random
import numpy as np

def qsHelper(a,low,high):
   if(low + 10 <= high): 
      if low<high:
          piv = partition_median(a,low,high)
          qsHelper(a,low,piv-1)
          qsHelper(a,piv+1,high)
   else:
      insertion_median(a,low,high)
   


def insertion_median(a,low,high):
    for i in range(low+1,high+1):
        key = a[i]
        j = i-1
        while(j>=0 and key < a[j]):
            a[j+1] = a[j]
            j -= 1
        a[j+1] = key
        
     
def quickSort_median(a):
   qsHelper(a,0,len(a)-1) 
   print(a)
   


def partition_median(a,low,high):
   pindex = median(a, low, high, (low + high) // 2)
   a[low], a[pindex] = a[pindex], a[low]
   pivot = a[low]
   
   lptr = low
   rptr = high
   
   flag = False
   while not flag:

       while lptr <= rptr and a[lptr] <= pivot:
           lptr = lptr + 1

       while a[rptr] >= pivot and rptr >= lptr:
           rptr = rptr -1

       if rptr < lptr:
           flag = True
       else:
           a[lptr],a[rptr] =a[rptr],a[lptr]


   temp = pivot
   a[np.where(a==pivot)[0][0]] = a[rptr]
   a[rptr] = temp
  
   return rptr


def median(a, low, high, median):
  if a[low] < a[high]:
     
    return high if a[high] < a[median] else median
  else:
    return low if a[low] < a[median] else median


a= []
n = int(input("enter the size of input"))
x=random.randint(100000, size=(n))
a= x
start_time =time.time()
#a.sort()
quickSort_median(a.copy())
runtime = (time.time() - start_time)*1000
print("runtime in ms := ",runtime)
# Out:
# enter the size of input500
# [   75   520   674   979   981  1052  1137  1247  1430  1446  1823  1878
#   2373  3073  3082  3129  3336  3583  3828  3862  4000  4426  4493  4499
#   4621  4645  5056  5080  5225  5369  5477  5619  5630  6428  6482  6885
#   6999  7059  7130  7311  7739  7779  7850  7914  8039  8444  8572  8577
#   8627  8787  9142  9263  9393  9457  9663  9710 10534 10616 10771 10923
#  10934 10968 11100 11195 11674 11919 11946 12005 12101 12369 12955 12980
